# %% [markdown]
# <a href="https://colab.research.google.com/github/Anderson-Andre-P/ETL-cenipa/blob/main/ETL_Dados_de_ocorr%C3%AAncias_aeron%C3%A1uticas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Extração de dados

# %%
import pandas as pd
# !pip install pandera
import pandera as pa
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.4/122.4 KB 6.8 MB/s eta 0:00:00
# ...

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-e71ad858-d8dc-48f9-ae30-78404127f4cb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e71ad858-d8dc-48f9-ae30-78404127f4cb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ## Importando Dataframe

# %%
uri = "/content/ocorrencia.csv"

# %% [markdown]
# # Limpeza de dados

# %%
valores_ausentes = ['**','###!','####','****','*****','NULL']

# %%
df = pd.read_csv(uri, sep=";", parse_dates=['ocorrencia_dia'], dayfirst=True, na_values=valores_ausentes, engine='python', encoding='ISO-8859-1')
df.head(10)
# Out:
#    codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0              81027               81027               81027
# 1              81030               81030               81030
# 2              81023               81023               81023
# 3              81029               81029               81029
# 4              81025               81025               81025
# 5              81019               81019               81019
# 6              81022               81022               81022
# 7              81021               81021               81021
# 8              81009               81009               81009
# 9              81012               81012               81012
#
#    codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0               81027               81027          INCIDENTE GRAVE
# 1               81030               81030                INCIDENTE
# 2               81023               81023          INCIDENTE GRAVE
# ...

# %%
df.dtypes
# Out:
# codigo_ocorrencia                          int64
# codigo_ocorrencia1                         int64
# codigo_ocorrencia2                         int64
# codigo_ocorrencia3                         int64
# codigo_ocorrencia4                         int64
# ocorrencia_classificacao                  object
# ocorrencia_latitude                       object
# ocorrencia_longitude                      object
# ocorrencia_cidade                         object
# ocorrencia_uf                             object
# ocorrencia_pais                           object
# ocorrencia_aerodromo                      object
# ocorrencia_dia                    datetime64[ns]
# ocorrencia_hora                           object
# investigacao_aeronave_liberada            object
# investigacao_status                       object
# divulgacao_relatorio_numero               object
# divulgacao_relatorio_publicado            object
# divulgacao_dia_publicacao                 object
# ...

# %% [markdown]
# Como temos muitas colunas, vou excluir algumas para facilitar a análise

# %%
df.drop(columns = ['codigo_ocorrencia1', 
                   'codigo_ocorrencia3', 
                   'codigo_ocorrencia4', 
                   'ocorrencia_latitude', 
                   'ocorrencia_longitude', 
                   'ocorrencia_pais', 
                   'ocorrencia_pais', 
                   'investigacao_aeronave_liberada', 
                   'investigacao_status', 
                   'divulgacao_relatorio_numero', 
                   'divulgacao_relatorio_publicado', 
                   'divulgacao_dia_publicacao', 
                   'total_aeronaves_envolvidas', 
                   'ocorrencia_saida_pista'], inplace = True)

# %%
df.dtypes
# Out:
# codigo_ocorrencia                    int64
# codigo_ocorrencia2                   int64
# ocorrencia_classificacao            object
# ocorrencia_cidade                   object
# ocorrencia_uf                       object
# ocorrencia_aerodromo                object
# ocorrencia_dia              datetime64[ns]
# ocorrencia_hora                     object
# total_recomendacoes                  int64
# dtype: object

# %%
df.head(10)
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              81027               81027          INCIDENTE GRAVE
# 1              81030               81030                INCIDENTE
# 2              81023               81023          INCIDENTE GRAVE
# 3              81029               81029                INCIDENTE
# 4              81025               81025                INCIDENTE
# 5              81019               81019                 ACIDENTE
# 6              81022               81022                INCIDENTE
# 7              81021               81021                 ACIDENTE
# 8              81009               81009          INCIDENTE GRAVE
# 9              81012               81012                INCIDENTE
#
#    ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0          SÃO PAULO            SP                 SBSP     2022-10-09
# 1            VITÓRIA            ES                 SBVT     2022-10-09
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6769 entries, 0 to 6768
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   codigo_ocorrencia         6769 non-null   int64
#  1   codigo_ocorrencia2        6769 non-null   int64
#  2   ocorrencia_classificacao  6769 non-null   object
#  3   ocorrencia_cidade         6769 non-null   object
#  4   ocorrencia_uf             6769 non-null   object
#  5   ocorrencia_aerodromo      6769 non-null   object
#  6   ocorrencia_dia            6769 non-null   datetime64[ns]
#  7   ocorrencia_hora           6767 non-null   object
#  8   total_recomendacoes       6769 non-null   int64
# dtypes: datetime64[ns](1), int64(3), object(5)
# memory usage: 476.1+ KB

# %%
schema = pa.DataFrameSchema(
    columns = {
        "codigo_ocorrencia": pa.Column(pa.Int),
        "codigo_ocorrencia2": pa.Column(pa.Int),
        "ocorrencia_classificacao": pa.Column(pa.String),
        "ocorrencia_cidade": pa.Column(pa.String),
        "ocorrencia_uf": pa.Column(pa.String, pa.Check.str_length(2,2), nullable=True),
        "ocorrencia_aerodromo": pa.Column(pa.String, nullable=True),
        "ocorrencia_dia": pa.Column(pa.DateTime),
        "ocorrencia_hora": pa.Column(pa.String, pa.Check.str_matches(r'^([0-1]?[0-9]|[2][0-3]):([0-5][0-9])(:[0-5][0-9])?$'), nullable=False),
        "total_recomendacoes": pa.Column(pa.Int)   
    }
)

# %%
df.isna().sum()
# Out:
# codigo_ocorrencia           0
# codigo_ocorrencia2          0
# ocorrencia_classificacao    0
# ocorrencia_cidade           0
# ocorrencia_uf               0
# ocorrencia_aerodromo        0
# ocorrencia_dia              0
# ocorrencia_hora             2
# total_recomendacoes         0
# dtype: int64

# %%
nan_values = df.loc['codigo_ocorrencia':'total_recomendacoes'].isna()
print(nan_values)
# Out:
# Empty DataFrame
# Columns: [codigo_ocorrencia, codigo_ocorrencia2, ocorrencia_classificacao, ocorrencia_cidade, ocorrencia_uf, ocorrencia_aerodromo, ocorrencia_dia, ocorrencia_hora, total_recomendacoes]
# Index: []

# %%
df = df.dropna()

# %%
# df['ocorrencia_uf'] = df['ocorrencia_uf'].replace('***', '--')
df.replace(['**', '***', '###!','####','****','*****','NULL'], pd.NA, inplace=True)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:5238: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().replace(

# %%
df.isna().sum()
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  4
# ocorrencia_aerodromo        2417
# ocorrencia_dia                 0
# ocorrencia_hora                0
# total_recomendacoes            0
# dtype: int64

# %%
# df.fillna(10, inplace=True)

# %%
df.head(60)
# Out:
#     codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0               81027               81027          INCIDENTE GRAVE
# 1               81030               81030                INCIDENTE
# 2               81023               81023          INCIDENTE GRAVE
# 3               81029               81029                INCIDENTE
# 4               81025               81025                INCIDENTE
# 5               81019               81019                 ACIDENTE
# 6               81022               81022                INCIDENTE
# 7               81021               81021                 ACIDENTE
# 8               81009               81009          INCIDENTE GRAVE
# 9               81012               81012                INCIDENTE
# 10              81017               81017          INCIDENTE GRAVE
# 11              81006               81006                INCIDENTE
# 12              81014               81014                 ACIDENTE
# ...

# %%
schema.validate(df)
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 81027               81027          INCIDENTE GRAVE
# 1                 81030               81030                INCIDENTE
# 2                 81023               81023          INCIDENTE GRAVE
# 3                 81029               81029                INCIDENTE
# 4                 81025               81025                INCIDENTE
# ...                 ...                 ...                      ...
# 6764              40324               40324                INCIDENTE
# 6765              39527               39527                 ACIDENTE
# 6766              40211               40211                INCIDENTE
# 6767              40349               40349                INCIDENTE
# 6768              40351               40351                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
df.loc[[5, 12, 6765]]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 5                 81019               81019                 ACIDENTE
# 12                81014               81014                 ACIDENTE
# 6765              39527               39527                 ACIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 5           PORTO ALEGRE            RS                 <NA>     2022-10-03
# 12             BOA VISTA            RR                 <NA>     2022-09-27
# 6765  LUCAS DO RIO VERDE            MT                 <NA>     2010-01-04
#
#      ocorrencia_hora  total_recomendacoes
# 5           20:50:00                    0
# 12          00:00:00                    0
# 6765        17:30:00                    0

# %%
df.loc[df.ocorrencia_cidade == 'ITAJUBÁ']
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 39                80976               80976                INCIDENTE
# 606               80305               80305                INCIDENTE
# 3799              53010               53010                INCIDENTE
# 4428              50271               50271                INCIDENTE
# 5053              46626               46626                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 39             ITAJUBÁ            MG                 SNHH     2022-09-09
# 606            ITAJUBÁ            MG                 SNHH     2021-09-21
# 3799           ITAJUBÁ            MG                 SNHH     2014-12-15
# 4428           ITAJUBÁ            MG                 <NA>     2013-11-08
# 5053           ITAJUBÁ            MG                 SNHH     2012-11-29
#
#      ocorrencia_hora  total_recomendacoes
# 39          15:30:00                    0
# ...

# %% [markdown]
# # Transformação de dados

# %%
schema.validate(df)
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 81027               81027          INCIDENTE GRAVE
# 1                 81030               81030                INCIDENTE
# 2                 81023               81023          INCIDENTE GRAVE
# 3                 81029               81029                INCIDENTE
# 4                 81025               81025                INCIDENTE
# ...                 ...                 ...                      ...
# 6764              40324               40324                INCIDENTE
# 6765              39527               39527                 ACIDENTE
# 6766              40211               40211                INCIDENTE
# 6767              40349               40349                INCIDENTE
# 6768              40351               40351                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
df.loc[21:27]
# Out:
#     codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 21              80995               80995                INCIDENTE
# 22              80996               80996                INCIDENTE
# 23              80994               80994                INCIDENTE
# 24              80990               80990                INCIDENTE
# 25              80989               80989                INCIDENTE
# 26              81007               81007                INCIDENTE
# 27              80987               80987                INCIDENTE
#
#    ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 21            URUARÁ            PA                 <NA>     2022-09-20
# 22       CAMPO LARGO            PR                 <NA>     2022-09-20
# 23          CURITIBA            PR                 SBCT     2022-09-19
# 24           SOCORRO            SP                 **NI     2022-09-17
# 25    BELO HORIZONTE            MG                 SBBH     2022-09-16
# ...

# %%
filtro_ocorrencia_aerodromo = df.ocorrencia_aerodromo.isnull()
filtro_ocorrencia_uf = df.ocorrencia_uf.isna()
df.loc[filtro_ocorrencia_aerodromo & filtro_ocorrencia_uf]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 320               80631               80631                INCIDENTE
# 4541              49474               49474                 ACIDENTE
#
#          ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 320       NÃO IDENTIFICADA          <NA>                 <NA>     2022-04-04
# 4541  ÁGUAS INTERNACIONAIS          <NA>                 <NA>     2013-09-02
#
#      ocorrencia_hora  total_recomendacoes
# 320         11:15:00                    0
# 4541        02:54:00                    0

# %%
# ocorrências acontecidas nos dias 01 a 15 de Abril de 2021
filtro_ano = df.ocorrencia_dia.dt.year == 2021
filtro_mes = df.ocorrencia_dia.dt.month == 4
filtro_dia_inicio = df.ocorrencia_dia.dt.day > 1 
filtro_dia_fim = df.ocorrencia_dia.dt.day < 15
df.loc[filtro_ano & filtro_mes & filtro_dia_inicio & filtro_dia_fim]
# Out:
#      codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 838              80021               80021                INCIDENTE
# 839              80095               80095                INCIDENTE
# 840              80020               80020                INCIDENTE
# 841              80022               80022                INCIDENTE
# 842              80030               80030                INCIDENTE
# 843              80032               80032          INCIDENTE GRAVE
# 844              80019               80019                 ACIDENTE
# 845              80029               80029                INCIDENTE
# 846              80031               80031          INCIDENTE GRAVE
# 847              80017               80017          INCIDENTE GRAVE
# 848              80028               80028                INCIDENTE
# 849              80015               80015                INCIDENTE
# 850              80018               80018                INCIDENTE
# ...
